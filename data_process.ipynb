# %%
import pandas as pd

# 讀取 Excel 格式不需要指定 encoding，但需要安裝 openpyxl (剛才我們裝過了)
file_path = "11502公告_3月份健保用藥項目價格檔異動.xlsx"
df = pd.read_excel(file_path)

df.head()
# Out:
#   全民健康保險藥品價格明細表  Unnamed: 1  Unnamed: 2  \
# 0            項次          文號        健保代碼
# 1             1  1150670164  X000341229
# 2             2  1140057976  BC28282100
# 3             3  1140057976  BC28283100
# 4             4  1140057976  BC28284100
#
#                                           Unnamed: 3    Unnamed: 4  \
# 0                                               藥品名稱            廠牌
# 1  ELFABRIO 2MG/ML CONCENTRATE FOR SOLUTION FOR I...  友華生技醫藥股份有限公司
# 2           LELIMIDE 25 (Lenalidomide Capsules 25mg)     凱沛爾藥品有限公司
# 3           LELIMIDE 10 (Lenalidomide Capsules 10mg)     凱沛爾藥品有限公司
# 4           LELIMIDE 15 (Lenalidomide Capsules 15mg)     凱沛爾藥品有限公司
#
#                      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0                         成分及含量         劑型        規格量       原核定價       新核定價
# 1  PEGUNIGALSIDASE ALFA 2 MG/ML        注射劑      10 ML      49554          0
# 2            LENALIDOMIDE 25 MG        膠囊劑        NaN       3173       1188
# ...

# %%
import os
import sqlite3
import pandas as pd
from sqlalchemy import create_engine

# 取得目前檔案所在的絕對路徑，確保跟 main.py 放在一起
db_path = os.path.join(os.getcwd(), 'nhi_data.db')
engine = create_engine(f'sqlite:///{db_path}')

# 寫入資料
df.to_sql('medicine_prices', engine, if_exists='replace', index=False)

# 測試：直接用 sqlite3 開開看，確認表真的在裡面
conn = sqlite3.connect(db_path)
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
conn.close()

print(f"資料庫位置: {db_path}")
print(f"現有的資料表: {tables}")
# Out:
# 資料庫位置: /workspaces/codespaces-blank/nhi_data.db
# 現有的資料表: [('medicine_prices',)]
